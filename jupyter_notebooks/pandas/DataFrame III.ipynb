# %%
import pandas as pd

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.where(bond["Box Office"] > 500)
# Out:
#                      Film    Year           Actor         Director  \
# 0                     NaN     NaN             NaN              NaN
# 1   From Russia with Love  1963.0    Sean Connery    Terence Young
# 2              Goldfinger  1964.0    Sean Connery     Guy Hamilton
# 3             Thunderball  1965.0    Sean Connery    Terence Young
# 4                     NaN     NaN             NaN              NaN
# 5     You Only Live Twice  1967.0    Sean Connery    Lewis Gilbert
# 6                     NaN     NaN             NaN              NaN
# 7                     NaN     NaN             NaN              NaN
# 8                     NaN     NaN             NaN              NaN
# 9                     NaN     NaN             NaN              NaN
# 10   The Spy Who Loved Me  1977.0     Roger Moore    Lewis Gilbert
# 11              Moonraker  1979.0     Roger Moore    Lewis Gilbert
# 12                    NaN     NaN             NaN              NaN
# ...

# %%
bond.mask(bond["Box Office"] > 500)
# Out:
#                                Film    Year           Actor  \
# 0                            Dr. No  1962.0    Sean Connery
# 1                               NaN     NaN             NaN
# 2                               NaN     NaN             NaN
# 3                               NaN     NaN             NaN
# 4                     Casino Royale  1967.0     David Niven
# 5                               NaN     NaN             NaN
# 6   On Her Majesty's Secret Service  1969.0  George Lazenby
# 7              Diamonds Are Forever  1971.0    Sean Connery
# 8                  Live and Let Die  1973.0     Roger Moore
# 9       The Man with the Golden Gun  1974.0     Roger Moore
# 10                              NaN     NaN             NaN
# 11                              NaN     NaN             NaN
# 12               For Your Eyes Only  1981.0     Roger Moore
# 13            Never Say Never Again  1983.0    Sean Connery
# 14                        Octopussy  1983.0     Roger Moore
# ...

# %% [markdown]
# ## set_index / reset_index

# %%
bond[["Film", "Year"]]
# Out:
#                                Film  Year
# 0                            Dr. No  1962
# 1             From Russia with Love  1963
# 2                        Goldfinger  1964
# 3                       Thunderball  1965
# 4                     Casino Royale  1967
# 5               You Only Live Twice  1967
# 6   On Her Majesty's Secret Service  1969
# 7              Diamonds Are Forever  1971
# 8                  Live and Let Die  1973
# 9       The Man with the Golden Gun  1974
# 10             The Spy Who Loved Me  1977
# 11                        Moonraker  1979
# 12               For Your Eyes Only  1981
# 13            Never Say Never Again  1983
# 14                        Octopussy  1983
# 15                 A View to a Kill  1985
# 16             The Living Daylights  1987
# 17                  Licence to Kill  1989
# 18                        GoldenEye  1995
# 19              Tomorrow Never Dies  1997
# 20          The World Is Not Enough  1999
# ...

# %%
bond["Film"][0:5]
# Out:
# 0                   Dr. No
# 1    From Russia with Love
# 2               Goldfinger
# 3              Thunderball
# 4            Casino Royale
# Name: Film, dtype: object

# %%
bond.set_index(keys = "Film", inplace = True)

# %%
bond.reset_index(drop = False, inplace = True)

# %%
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %% [markdown]
# ### Retrive rows by Index Label .loc[ ]

# %%
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.set_index(keys = "Film", inplace = True)
bond.sort_index(inplace = True)
bond.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [87], in <cell line: 1>()
# ----> 1 bond.set_index(keys = "Film", inplace = True)
#       2 bond.sort_index(inplace = True)
#       3 bond.head()
#
# File ~\.conda\envs\pandas_playground\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\.conda\envs\pandas_playground\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# ...

# %%
bond.loc["Die Another Day"]
# Out:
# Year                           2002
# Actor                Pierce Brosnan
# Director               Lee Tamahori
# Box Office                    465.4
# Budget                        154.2
# Bond Actor Salary              17.9
# Name: Die Another Day, dtype: object

# %%
bond.loc[["Casino Royale", "Die Another Day"]]
# Out:
#                  Year           Actor         Director  Box Office  Budget  \
# Film
# Casino Royale    2006    Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale    1967     David Niven       Ken Hughes       315.0    85.0
# Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4   154.2
#
#                  Bond Actor Salary
# Film
# Casino Royale                  3.3
# Casino Royale                  NaN
# Die Another Day               17.9

# %%
bond.loc["Die Another Day":"Goldfinger"]
#bond.loc["Goldfinger"]
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
#
#                        Budget  Bond Actor Salary
# Film
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6
# GoldenEye                76.9                5.1
# Goldfinger               18.6                3.2

# %%
bond.loc[:"Goldfinger"]
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen       275.2
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# Casino Royale           145.3                3.3
# ...

# %%
bond.loc["Goldfinger", "Actor"]
# Out:
# 'Sean Connery'

# %%
bond.loc["Casino Royale", "Actor"]
# Out:
# Film
# Casino Royale    Daniel Craig
# Casino Royale     David Niven
# Name: Actor, dtype: object

# %%
bond.loc["Goldfinger":, ["Actor", "Director", "Year"]]
# Out:
#                                           Actor            Director  Year
# Film
# Goldfinger                         Sean Connery        Guy Hamilton  1964
# Licence to Kill                  Timothy Dalton           John Glen  1989
# Live and Let Die                    Roger Moore        Guy Hamilton  1973
# Moonraker                           Roger Moore       Lewis Gilbert  1979
# Never Say Never Again              Sean Connery      Irvin Kershner  1983
# Octopussy                           Roger Moore           John Glen  1983
# On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt  1969
# Quantum of Solace                  Daniel Craig        Marc Forster  2008
# Skyfall                            Daniel Craig          Sam Mendes  2012
# Spectre                            Daniel Craig          Sam Mendes  2015
# The Living Daylights             Timothy Dalton           John Glen  1987
# The Man with the Golden Gun         Roger Moore        Guy Hamilton  1974
# ...

# %%
bond.loc[:,:]
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.iloc[0]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[:5, 1:]
# Out:
#                                Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill         Roger Moore        John Glen       275.2    54.5
# Casino Royale           Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale            David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever    Sean Connery     Guy Hamilton       442.5    34.7
# Die Another Day       Pierce Brosnan     Lee Tamahori       465.4   154.2
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                    17.9

# %%
bond.loc["Goldfinger", "Actor"] = "Sean Connery"

# %%
bond.loc["Goldfinger", "Actor"]
# Out:
# 'Sir Sean Connery'

# %%
bond.loc["Goldfinger"]
# Out:
# Year                             1964
# Actor                Sir Sean Connery
# Director                 Guy Hamilton
# Box Office                      820.4
# Budget                           18.6
# Bond Actor Salary                 3.2
# Name: Goldfinger, dtype: object

# %%
actor_sean_connery = bond["Actor"] == "Sean Connery"

# %%
bond.loc[actor_sean_connery, "Actor"] = "Sir Sean Connery"

# %%
bond
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %% [markdown]
# ### Rename Index and Columns

# %%
bond.sort_index(inplace = True)

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(mapper = {"Goldfinger": "Gold Finger",
                     "GoldenEye": "Golden Eye"}, axis = 0)
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# Golden Eye                       1995  Pierce Brosnan     Martin Campbell
# Gold Finger                      1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
mapper = {i: i+" test" for i in bond.index}
print(mapper)
bond.rename(mapper = mapper, axis = "rows")
# Out:
# {'A View to a Kill': 'A View to a Kill test', 'Casino Royale': 'Casino Royale test', 'Diamonds Are Forever': 'Diamonds Are Forever test', 'Die Another Day': 'Die Another Day test', 'Dr. No': 'Dr. No test', 'For Your Eyes Only': 'For Your Eyes Only test', 'From Russia with Love': 'From Russia with Love test', 'GoldenEye': 'GoldenEye test', 'Goldfinger': 'Goldfinger test', 'Licence to Kill': 'Licence to Kill test', 'Live and Let Die': 'Live and Let Die test', 'Moonraker': 'Moonraker test', 'Never Say Never Again': 'Never Say Never Again test', 'Octopussy': 'Octopussy test', "On Her Majesty's Secret Service": "On Her Majesty's Secret Service test", 'Quantum of Solace': 'Quantum of Solace test', 'Skyfall': 'Skyfall test', 'Spectre': 'Spectre test', 'The Living Daylights': 'The Living Daylights test', 'The Man with the Golden Gun': 'The Man with the Golden Gun test', 'The Spy Who Loved Me': 'The Spy Who Loved Me test', 'The World Is Not Enough': 'The World Is Not Enough test', 'Thunderbal
# ...

# %%
bond.rename(index = mapper)
# Out:
#                                       Year           Actor  \
# Film
# A View to a Kill test                 1985     Roger Moore
# Casino Royale test                    2006    Daniel Craig
# Casino Royale test                    1967     David Niven
# Diamonds Are Forever test             1971    Sean Connery
# Die Another Day test                  2002  Pierce Brosnan
# Dr. No test                           1962    Sean Connery
# For Your Eyes Only test               1981     Roger Moore
# From Russia with Love test            1963    Sean Connery
# GoldenEye test                        1995  Pierce Brosnan
# Goldfinger test                       1964    Sean Connery
# Licence to Kill test                  1989  Timothy Dalton
# Live and Let Die test                 1973     Roger Moore
# Moonraker test                        1979     Roger Moore
# Never Say Never Again test            1983    Sean Connery
# Octopussy test                        1983     Roger Moore
# ...

# %%
bond.rename (mapper = {"Year": "Release Year", "Box Office" : "Revenue"}, axis = 1)
# Out:
#                                  Release Year           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr. No                                   1962    Sean Connery
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# GoldenEye                                1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
bond.rename (columns = {"Year": "Release Year", "Box Office" : "Revenue"})
# Out:
#                                  Release Year           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr. No                                   1962    Sean Connery
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# GoldenEye                                1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %% [markdown]
# ### Delete Rows and Columns

# %%
bond = pd.read_csv("jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
roger = bond["Actor"] == "Roger Moore"
bond.drop(labels = bond[roger].index)
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# ...

# %%
bond.drop(labels = "Year", axis = 1)
# Out:
#                                           Actor            Director  \
# Film
# A View to a Kill                    Roger Moore           John Glen
# Casino Royale                      Daniel Craig     Martin Campbell
# Casino Royale                       David Niven          Ken Hughes
# Diamonds Are Forever               Sean Connery        Guy Hamilton
# Die Another Day                  Pierce Brosnan        Lee Tamahori
# Dr. No                             Sean Connery       Terence Young
# For Your Eyes Only                  Roger Moore           John Glen
# From Russia with Love              Sean Connery       Terence Young
# GoldenEye                        Pierce Brosnan     Martin Campbell
# Goldfinger                         Sean Connery        Guy Hamilton
# Licence to Kill                  Timothy Dalton           John Glen
# Live and Let Die                    Roger Moore        Guy Hamilton
# Moonraker                           Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# ### Random Sample

# %%
bond.sample()
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                  Bond Actor Salary
# Film
# Die Another Day               17.9

# %%
bond.sample(n =5)
# Out:
#                                  Year           Actor       Director  \
# Film
# From Russia with Love            1963    Sean Connery  Terence Young
# Spectre                          2015    Daniel Craig     Sam Mendes
# The World Is Not Enough          1999  Pierce Brosnan  Michael Apted
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# Octopussy                        1983     Roger Moore      John Glen
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# From Russia with Love                 543.8    12.6                1.6
# Spectre                               726.7   206.3                NaN
# The World Is Not Enough               439.5   158.3               13.5
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Octopussy                             373.8    53.9                7.8

# %%
bond.sample(frac = .3)
# Out:
#                       Year           Actor      Director  Box Office  Budget  \
# Film
# Diamonds Are Forever  1971    Sean Connery  Guy Hamilton       442.5    34.7
# Skyfall               2012    Daniel Craig    Sam Mendes       943.5   170.2
# Spectre               2015    Daniel Craig    Sam Mendes       726.7   206.3
# For Your Eyes Only    1981     Roger Moore     John Glen       449.4    60.2
# The Living Daylights  1987  Timothy Dalton     John Glen       313.5    68.8
# A View to a Kill      1985     Roger Moore     John Glen       275.2    54.5
# Goldfinger            1964    Sean Connery  Guy Hamilton       820.4    18.6
# Die Another Day       2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                       Bond Actor Salary
# Film
# Diamonds Are Forever                5.8
# Skyfall                            14.5
# Spectre                             NaN
# For Your Eyes Only                  NaN
# The Living Daylights                5.2
# ...

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.nlargest(n = 3, columns = "Budget", keep = 'last')
# Out:
#                    Year         Actor      Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig    Sam Mendes       726.7   206.3
# Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig    Sam Mendes       943.5   170.2
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Quantum of Solace                8.1
# Skyfall                         14.5

# %%
bond.nlargest(n = 3, columns = ["Budget", "Box Office"])
# Out:
#                    Year         Actor      Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig    Sam Mendes       726.7   206.3
# Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig    Sam Mendes       943.5   170.2
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Quantum of Solace                8.1
# Skyfall                         14.5

# %%
bond.nsmallest(n =3 , columns = "Box Office")
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.where((bond["Actor"] == "Roger Moore") & (bond["Year"] > 1980))
# Out:
#                                    Year        Actor   Director  Box Office  \
# Film
# A View to a Kill                 1985.0  Roger Moore  John Glen       275.2
# Casino Royale                       NaN          NaN        NaN         NaN
# Casino Royale                       NaN          NaN        NaN         NaN
# Diamonds Are Forever                NaN          NaN        NaN         NaN
# Die Another Day                     NaN          NaN        NaN         NaN
# Dr. No                              NaN          NaN        NaN         NaN
# For Your Eyes Only               1981.0  Roger Moore  John Glen       449.4
# From Russia with Love               NaN          NaN        NaN         NaN
# GoldenEye                           NaN          NaN        NaN         NaN
# Goldfinger                          NaN          NaN        NaN         NaN
# Licence to Kill                     NaN          NaN        NaN         NaN
# ...

# %%
bond.query('Actor == "Roger Moore" and Year > 1980')
# Out:
#                     Year        Actor   Director  Box Office  Budget  \
# Film
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
#
#                     Bond Actor Salary
# Film
# A View to a Kill                  9.1
# For Your Eyes Only                NaN
# Octopussy                         7.8

# %%
directors = bond["Director"]

# %%
directors["A View to a Kill"] = "Mister John Glen"
# Out:
# C:\Users\Koushik\AppData\Local\Temp\ipykernel_14692\2347769033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directors["A View to a Kill"] = "Mister John Glen"

# %%
directors
# Out:
# Film
# A View to a Kill                     Mister John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# ...

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore    Mister John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
directors = bond["Director"].copy()

# %%
directors
# Out:
# Film
# A View to a Kill                            John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# ...

# %%
directors["A View to a Kill"] = "Mister John Glen"

# %%
directors
# Out:
# Film
# A View to a Kill                     Mister John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# ...

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
director = pd.read_csv("jamesbond.csv", usecols = ["Film", "Year"], index_col = "Year").squeeze()

# %%
director
# Out:
# Year
# 1962                             Dr. No
# 1963              From Russia with Love
# 1964                         Goldfinger
# 1965                        Thunderball
# 1967                      Casino Royale
# 1967                You Only Live Twice
# 1969    On Her Majesty's Secret Service
# 1971               Diamonds Are Forever
# 1973                   Live and Let Die
# 1974        The Man with the Golden Gun
# 1977               The Spy Who Loved Me
# 1979                          Moonraker
# 1981                 For Your Eyes Only
# 1983              Never Say Never Again
# 1983                          Octopussy
# 1985                   A View to a Kill
# 1987               The Living Daylights
# 1989                    Licence to Kill
# 1995                          GoldenEye
# 1997                Tomorrow Never Dies
# 1999            The World Is Not Enough
# 2002                    Die Another Day
# 2006                      Casino Royale
# ...
