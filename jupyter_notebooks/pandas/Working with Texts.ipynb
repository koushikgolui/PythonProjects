# %%
import pandas as pd

# %%
chicago = pd.read_csv("chicago.csv").dropna(how = "all")
chicago["Department"] = chicago["Department"].astype("category")

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago["Name"].str.capitalize()
# Out:
# 0            Aaron,  elvia j
# 1          Aaron,  jeffery m
# 2             Aaron,  karina
# 3        Aaron,  kimberlei r
# 4        Abad jr,  vicente m
#                 ...
# 32058     Zygowicz,  peter j
# 32059      Zymantas,  mark e
# 32060    Zyrkowski,  carlo e
# 32061    Zyskowski,  dariusz
# 32062                    NaN
# Name: Name, Length: 32063, dtype: object

# %%
chicago["Position Title"].str.title()
# Out:
# 0                Water Rate Taker
# 1                  Police Officer
# 2                  Police Officer
# 3        Chief Contract Expediter
# 4               Civil Engineer Iv
#                    ...
# 32058              Police Officer
# 32059              Police Officer
# 32060              Police Officer
# 32061     Chief Data Base Analyst
# 32062                         NaN
# Name: Position Title, Length: 32063, dtype: object

# %%
chicago["Department"].str.len()
# Out:
# 0        11.0
# 1         6.0
# 2         6.0
# 3        16.0
# 4        11.0
#          ...
# 32058     6.0
# 32059     6.0
# 32060     6.0
# 32061     4.0
# 32062     NaN
# Name: Department, Length: 32063, dtype: float64

# %%
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
chicago["Department"] = chicago["Department"].str.replace("MGMNT", "MANAGEMENT")

# %%
chicago.head(5)
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER  WATER MANAGEMENT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV  WATER MANAGEMENT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago[chicago["Position Title"].str.lower().str.contains("water")]
# Out:
#                        Name                                 Position Title  \
# 0           AARON,  ELVIA J                               WATER RATE TAKER
# 554      ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671         ANDER,  PERRY A                               WATER CHEMIST II
# 685     ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702       ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# ...                     ...                                            ...
# 29669        VERMA,  ANUPAM           MANAGING ENGINEER - WATER MANAGEMENT
# 30239   WASHINGTON,  JOSEPH                              WATER CHEMIST III
# 30544       WEST,  THOMAS R                   GEN SUPT OF WATER MANAGEMENT
# 30991    WILLIAMS,  MATTHEW             FOREMAN OF WATER PIPE CONSTRUCTION
# 31405  WOODRIDGE,  ROBERT L             FOREMAN OF WATER PIPE CONSTRUCTION
#
#              Department Employee Annual Salary
# ...

# %%
chicago[chicago["Position Title"].str.lower().str.startswith("water")]
# Out:
#                          Name           Position Title        Department  \
# 0             AARON,  ELVIA J         WATER RATE TAKER  WATER MANAGEMENT
# 671           ANDER,  PERRY A         WATER CHEMIST II  WATER MANAGEMENT
# 1054         ASHLEY,  KARMA T         WATER CHEMIST II  WATER MANAGEMENT
# 1079        ATKINS,  JOANNA M         WATER CHEMIST II  WATER MANAGEMENT
# 1181       AZEEM,  MOHAMMED A         WATER CHEMIST II  WATER MANAGEMENT
# ...                       ...                      ...               ...
# 28574      THREATT,  DENISE R  WATER QUALITY INSPECTOR  WATER MANAGEMENT
# 28602       TIGNOR,  DARRYL B         WATER RATE TAKER  WATER MANAGEMENT
# 28955  TRAVIS COOK,  LESLIE R         WATER RATE TAKER  WATER MANAGEMENT
# 29584        VELAZQUEZ,  JOHN         WATER RATE TAKER  WATER MANAGEMENT
# 30239     WASHINGTON,  JOSEPH        WATER CHEMIST III  WATER MANAGEMENT
#
#       Employee Annual Salary
# 0                  $90744.00
# 671                $82044.00
# ...

# %%
chicago[chicago["Position Title"].str.lower().str.endswith("inspector")]
# Out:
#                         Name                     Position Title  \
# 51     ABUBAKER,  MOHAMMED G     SENIOR ENVIRONMENTAL INSPECTOR
# 141       ADAMS,  REGINALD K                 PLUMBING INSPECTOR
# 142         ADAMS,  ROBERT L  VENTILATION AND FURNACE INSPECTOR
# 159     ADEBAYO,  BENJAMIN B    BUILDING/CONSTRUCTION INSPECTOR
# 523         ALONSO,  EDUARDO    BUILDING/CONSTRUCTION INSPECTOR
# ...                      ...                                ...
# 30574     WHIRITY,  MARTIN P    SENIOR PUBLIC VEHICLE INSPECTOR
# 31294   WISNESKI,  RANDALL W    BUILDING/CONSTRUCTION INSPECTOR
# 31484      WORRILL,  OSCAR W              HOUSE DRAIN INSPECTOR
# 31495      WOULFE,  MARTIN J                 PLUMBING INSPECTOR
# 31783     ZAHDAN,  ZIYADEH D                 PLUMBING INSPECTOR
#
#              Department Employee Annual Salary
# 51               HEALTH              $78204.00
# 141           BUILDINGS             $100470.00
# 142           BUILDINGS              $94868.80
# ...

# %%
mask1 = chicago["Position Title"].str.lower().str.endswith("inspector")
mask2 = chicago["Department"].str.lower().str.contains("water")
chicago[mask1 & mask2]
# Out:
#                         Name            Position Title        Department  \
# 1034   ARZADON JR,  MANUEL D           MASON INSPECTOR  WATER MANAGEMENT
# 1350         BALL,  DONALD L     HOUSE DRAIN INSPECTOR  WATER MANAGEMENT
# 2801    BRENNAN,  JONATHON P        PLUMBING INSPECTOR  WATER MANAGEMENT
# 3702     CALLAHAN,  DONALD E           MASON INSPECTOR  WATER MANAGEMENT
# 3937     CARDIFF,  MICHAEL D        PLUMBING INSPECTOR  WATER MANAGEMENT
# 4448      CHAMBERS,  KEITH S        PLUMBING INSPECTOR  WATER MANAGEMENT
# 7535       DUFFY,  PATRICK K        PLUMBING INSPECTOR  WATER MANAGEMENT
# 8722          FLEMING,  ZANE        PLUMBING INSPECTOR  WATER MANAGEMENT
# 9079          FRANK,  ROBERT        PLUMBING INSPECTOR  WATER MANAGEMENT
# 9580         GARCIA,  MANUEL        PLUMBING INSPECTOR  WATER MANAGEMENT
# 9953        GIBSON JR,  FRED     HOUSE DRAIN INSPECTOR  WATER MANAGEMENT
# 10911    GRUENKE,  RICHARD J        PLUMBING INSPECTOR  WATER MANAGEMENT
# ...

# %%
chicago["Name"].str.split(",").str.get(0)
# Out:
# 0            AARON
# 1            AARON
# 2            AARON
# 3            AARON
# 4          ABAD JR
#            ...
# 32057      ZYGADLO
# 32058     ZYGOWICZ
# 32059     ZYMANTAS
# 32060    ZYRKOWSKI
# 32061    ZYSKOWSKI
# Name: Name, Length: 32062, dtype: object

# %%
chicago["Name"].str.split(",", expand=True).get(0)
# Out:
# 0            AARON
# 1            AARON
# 2            AARON
# 3            AARON
# 4          ABAD JR
#            ...
# 32057      ZYGADLO
# 32058     ZYGOWICZ
# 32059     ZYMANTAS
# 32060    ZYRKOWSKI
# 32061    ZYSKOWSKI
# Name: 0, Length: 32062, dtype: object

# %%
chicago["Name"].str.split(",", expand = True).get(1).str.strip().str.split(" ", expand = True).get(0)
# Out:
# 0            ELVIA
# 1          JEFFERY
# 2           KARINA
# 3        KIMBERLEI
# 4          VICENTE
#            ...
# 32057      MICHAEL
# 32058        PETER
# 32059         MARK
# 32060        CARLO
# 32061      DARIUSZ
# Name: 0, Length: 32062, dtype: object

# %%
chicago["Position Title"].str.split(" ", expand = True, n = 1)
# Out:
#             0                           1
# 0       WATER                  RATE TAKER
# 1      POLICE                     OFFICER
# 2      POLICE                     OFFICER
# 3       CHIEF          CONTRACT EXPEDITER
# 4       CIVIL                 ENGINEER IV
# ...       ...                         ...
# 32057     FRM  OF MACHINISTS - AUTOMOTIVE
# 32058  POLICE                     OFFICER
# 32059  POLICE                     OFFICER
# 32060  POLICE                     OFFICER
# 32061   CHIEF           DATA BASE ANALYST
#
# [32062 rows x 2 columns]
